# %%
# Tools for Data Science Final Project

# %% [markdown]
# ## Introduction
# This notebook showcases basic concepts in data science, including languages, libraries, tools, and simple arithmetic operations using code cells.

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ## Data Science Libraries
# Common libraries used in data science are:
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Spark       |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# Below are examples of simple arithmetic expressions executed in Python.

# %%
# Multiply and add numbers
result = (5 * 4) + 3
result
# Out:
# 23

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
hours
# Out:
# 2.0

# %% [markdown]
# **Objectives:**
#
# - List data science languages
# - List data science libraries
# - Create a table of tools
# - Perform arithmetic operations in code
# - Convert minutes to hours using Python

# %% [markdown]
# ## Author
# "Harish"
